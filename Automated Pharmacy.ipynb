# %%
import pandas as pd

# %%
medicineList = [
    "Panadol",
    "Augmentin",
    "Ciprofloxacin",
    "Atorvastatin",
    "Omeprazole",
    "Metformin",
    "Aspirin",
    "Salbutamol Inhaler",
    "Amlodipine",
    "Amoxicillin",
    "Metronidazole",
    "Ibuprofen",
    "Gliclazide",
    "Losartan",
    "Montelukast",
    "Vitamin C",
    "Levocetirizine",
    "Erythromycin",
    "Atenolol",
    "Codeine"
]


quantities = [100, 50, 70, 30, 20, 60, 90, 40, 25, 55, 45, 80, 35, 15, 10, 45, 25, 35, 50, 25]

# %%
data = {
    'Medicine': medicineList,
    'Quantity': quantities
}

df = pd.DataFrame(data)
df.head()
# Out:
#         Medicine  Quantity
# 0        Panadol       100
# 1      Augmentin        50
# 2  Ciprofloxacin        70
# 3   Atorvastatin        30
# 4     Omeprazole        20

# %%
df.to_csv('MedicineList.csv', index=False)
